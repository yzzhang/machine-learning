# %% [markdown]
# # Deep Learning for Natural Language Processing Using word2vec-keras
# ## A deep learning approach for NLP by combining Word2vec with LSTM
#
# Refer to the article [Deep Learning for Natural Language Processing Using word2vec-keras](https://medium.com/@zhangyuefeng1/deep-learning-for-natural-language-processing-using-word2vec-keras-d9a240c7bb9d)

# %%
from sklearn.datasets import fetch_20newsgroups
from word2vec_keras import Word2VecKeras
from pprint import pprint
import pandas as pd
import matplotlib.pyplot as plt
import itertools
import numpy as np
import nltk
import string
import re
import ast # abstract syntax tree: https://docs.python.org/3/library/ast.html
from sklearn.model_selection import train_test_split
import mlflow
import mlflow.sklearn

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Preprocessing

# %%
class Preprocessing(object):
    def __init__(self, data, target_column_name='body_text_clean'):
        self.data = data
        self.feature_name = target_column_name
        
    def remove_punctuation(self, text):
        # string.punctuation: '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
        text_nopunct = "".join([char for char in text if char not in string.punctuation])# It will discard all punctuations
        return text_nopunct
    
    def tokenize(self, text):
        #W+ Matches one or more characters which are not word character.
        tokens = re.split('\W+', text) 
        return tokens
    
    def remove_stopwords(self, tokenized_list):
        '''
        download stopwords zip file at: http://www.nltk.org/nltk_data/
        move the unzipped directory stopwords to: /Users/yuhuang/anaconda3/envs/deeplearning/nltk_data/corpora
        '''
        # Remove all English Stopwords
        stopword = nltk.corpus.stopwords.words('english')
        text = [word for word in tokenized_list if word not in stopword]
        return text   

    def stemming(self, tokenized_text):
        ps = nltk.PorterStemmer()
        text = [ps.stem(word) for word in tokenized_text]
        return text
    
    def lemmatizing(self, tokenized_text):
        '''
        download wordnet at: http://www.nltk.org/nltk_data/
        move wprdnet.zip file to: /Users/yuhuang/anaconda3/envs/deeplearning/nltk_data/corpora
        '''
        wn = nltk.WordNetLemmatizer()
        text = [wn.lemmatize(word) for word in tokenized_text]
        return text
    
    def tokens_to_string(self, tokens_string):
        try:
            list_obj = ast.literal_eval(tokens_string)
            text = " ".join(list_obj)
        except:
            text = None
        return text
    
    def dropna(self):
        feature_name = self.feature_name
        if self.data[feature_name].isnull().sum() > 0:
            column_list=[feature_name]
            self.data = self.data.dropna(subset=column_list)
            return self.data
        
    def preprocessing(self):
        self.data['body_text_nopunc'] = self.data['body_text'].apply(lambda x: self.remove_punctuation(x))
        self.data['body_text_tokenized'] = self.data['body_text_nopunc'].apply(lambda x: self.tokenize(x.lower())) 
        self.data['body_text_nostop'] = self.data['body_text_tokenized'].apply(lambda x: self.remove_stopwords(x))
        self.data['body_text_stemmed'] = self.data['body_text_nostop'].apply(lambda x: self.stemming(x))
        self.data['body_text_lemmatized'] = self.data['body_text_nostop'].apply(lambda x: self.lemmatizing(x))
        
        # save cleaned dataset into csv file and load back
        self.save()
        self.load()
        
        self.data[self.feature_name] = self.data['body_text_lemmatized'].apply(lambda x: self.tokens_to_string(x))
        
        self.dropna() # error occurred!!!
        
        drop_columns = ['body_text_nopunc', 'body_text_tokenized', 'body_text_nostop', 'body_text_stemmed', 'body_text_lemmatized'] 
        self.data.drop(drop_columns, axis=1, inplace=True)
        
        
        return self.data
    
    def save(self, filepath="./data/spam_cleaned.csv"):
        self.data.to_csv(filepath, index=False, sep=',')  
        
    def load(self, filepath="./data/spam_cleaned.csv"):
        self.data = pd.read_csv(filepath)
        return self.data
# Out:
# <>:13: DeprecationWarning: invalid escape sequence \W
# <>:13: DeprecationWarning: invalid escape sequence \W
# <>:13: DeprecationWarning: invalid escape sequence \W
# <ipython-input-2-326cbe965034>:13: DeprecationWarning: invalid escape sequence \W
#   tokens = re.split('\W+', text)

# %% [markdown]
# ## Classification

# %%
class SpamClassifier(object):
    def __init__(self):
        self.model = Word2VecKeras()
        
    def load_data(self):
        '''
        data source:
        https://www.kaggle.com/uciml/sms-spam-collection-dataset
        text encoding must use ISO-8859-1, not the default utf-8
        '''
        column_names = ['label', 'body_text', 'missing_1', 'missing_2', 'missing_3']
        data = pd.read_csv('./data/spam.csv', encoding = "ISO-8859-1")
        data.columns = column_names
        data.drop(['missing_1', 'missing_2', 'missing_3'], axis=1, inplace=True)
        self.raw_data = data.sample(frac=1.0) 
        
        print('Rows: {}, Columns: {}'.format(self.raw_data.shape[0], self.raw_data.shape[1]))
        print("Total rows: {}, spam: {}, ham: {}".format(len(self.raw_data),
                                                       len(self.raw_data[self.raw_data['label']=='spam']),
                                                       len(self.raw_data[self.raw_data['label']=='ham'])))
        
        print("Total number of missing labels: {}".format(self.raw_data['label'].isnull().sum()))
        print("Total number of missging text: {}".format(self.raw_data['body_text'].isnull().sum()))
        
        return self.raw_data
    
    def split_data(self):
        # Shuffle and split the data into training and testing subsets
        self.x_train, self.x_test, self.y_train, self.y_test = train_test_split(self.x, self.y, test_size=0.25, random_state=42)
        
    def numpy_to_list(self):
        '''
        convert Numpy ndarray to Python list for word2vec-keras API
        '''
        self.x_train = self.x_train.tolist()
        self.y_train = self.y_train.tolist()
        self.x_test  = self.x_test.tolist()
        self.y_test  = self.y_test.tolist()
    
    def prepare_data(self, feature, label='label'):
        self.load_data()
        pp = Preprocessing(self.raw_data)
        self.data = pp.preprocessing()
        
        print('self.data[feture] type: ', type(self.data))
        
        self.x = self.data[feature].values
        self.y = self.data[label].values
        self.split_data()
        self.numpy_to_list()
        
        return self.data
        
    def train_model(self):
        '''
        w2v_min_count
        
        RuntimeError: you must first build vocabulary before training the model.
        
        You configured a min_count of 50 (-m 50), but maybe there is no word in 
        your vocabulary with frequency greater than 50, hence your vocab will be empty and 
        gensim returns the error. Try a lower min_count ...
        '''
        self.w2v_size = 300
        self.w2v_min_count = 1 # 5
        self.w2v_epochs = 100
        self.k_epochs = 5 # 32
        self.k_lstm_neurons = 512
        self.k_max_sequence_len = 1000
        
        self.model.train(self.x_train, self.y_train, 
            w2v_size=self.w2v_size, 
            w2v_min_count=self.w2v_min_count, 
            w2v_epochs=self.w2v_epochs, 
            k_epochs=self.k_epochs, 
            k_lstm_neurons=self.k_lstm_neurons, 
            k_max_sequence_len=self.k_max_sequence_len, 
            k_hidden_layer_neurons=[])
        
    def evaluate(self):
        self.result = self.model.evaluate(self.x_test, self.y_test)
        self.accuracy = self.result["ACCURACY"]
        self.clf_report_df = pd.DataFrame(self.result["CLASSIFICATION_REPORT"])
        self.cnf_matrix = self.result["CONFUSION_MATRIX"]
        print('Confusion Matrix: ', self.cnf_matrix)
        return self.result
    
    def predict(self, idx=1):
        print("LABEL:", self.y_test[idx])
        print("TEXT :", self.x_test[idx])
        print("/n============================================")
        print("PREDICTION:", self.model.predict(self.x_test[idx]))
        
    def mlFlow(self, feature='body_text_clean'):
        np.random.seed(40)  
        with mlflow.start_run():
            self.prepare_data(feature=feature) # feature should be 'body_text' if no need to preprocessing
            self.train_model()
            self.evaluate()
            self.predict()
            mlflow.log_param("feature", feature) 
            mlflow.log_param("w2v_size", self.w2v_size)  
            mlflow.log_param("w2v_min_count", self.w2v_min_count)
            mlflow.log_param("w2v_epochs", self.w2v_epochs)
            mlflow.log_param("k_lstm_neurons", self.k_lstm_neurons)
            mlflow.log_param("k_max_sequence_len", self.k_max_sequence_len)
            mlflow.log_metric("accuracy", self.accuracy)
            mlflow.sklearn.log_model(self.model, "Word2Vec-Keras")

# %%
spam_clf = SpamClassifier()

# %%
spam_clf.mlFlow(feature='body_text')
# Out:
# /Users/yuhuang/anaconda3/envs/deeplearning/lib/python3.7/site-packages/py4j/java_collections.py:13: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import (
# Rows: 5572, Columns: 2
# Total rows: 5572, spam: 747, ham: 4825
# Total number of missing labels: 0
# Total number of missging text: 0
# 2019-11-03 19:30:43,615 : INFO : Build & train Word2Vec model
# 2019-11-03 19:30:43,616 : INFO : collecting all words and their counts
# 2019-11-03 19:30:43,617 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-11-03 19:30:43,626 : INFO : collected 6702 word types from a corpus of 58956 raw words and 4177 sentences
# 2019-11-03 19:30:43,627 : INFO : Loading a fresh vocabulary
# 2019-11-03 19:30:43,638 : INFO : effective_min_count=1 retains 6702 unique words (100% of original 6702, drops 0)
# 2019-11-03 19:30:43,638 : INFO : effective_min_count=1 leaves 58956 word corpus (100% of original 58956, drops 0)
# 2019-11-03 19:30:43,655 : INFO : deleting the raw counts dictionary of 6702 items
# 2019-11-03 19:30:43,656 : INFO : sample=0.001 downsamples 63 most-common words
# 2019-11-03 19:30:43,656 : INFO : downsampling leaves estimated 48579 word corpus (82.4% of prior 58956)
# 2019-11-03 19:30:43,668 : INFO : estimated required memory for 6702 words and 300 dimensions: 19435800 bytes
# 2019-11-03 19:30:43,668 : INFO : resetting layer weights
# 2019-11-03 19:30:43,751 : INFO : training model with 16 workers on 6702 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2019-11-03 19:30:43,761 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:43,762 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:43,763 : INFO : worker thread finished; awaiting finish of 13 more threads
# self.data[feture] type:  <class 'pandas.core.frame.DataFrame'>
# 2019-11-03 19:30:43,771 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:43,772 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:43,776 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:43,777 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:43,783 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:43,783 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:43,784 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:43,785 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:43,788 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:43,791 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:43,796 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:43,797 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:43,799 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:43,800 : INFO : EPOCH - 1 : training on 58956 raw words (48503 effective words) took 0.0s, 1157242 effective words/s
# 2019-11-03 19:30:43,810 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:43,816 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:43,817 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:43,817 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:43,819 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:43,822 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:43,823 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:43,824 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:43,830 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:43,832 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:43,833 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:43,837 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:43,838 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:43,844 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:43,846 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:43,848 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:43,849 : INFO : EPOCH - 2 : training on 58956 raw words (48534 effective words) took 0.0s, 1149166 effective words/s
# 2019-11-03 19:30:43,861 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:43,869 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:43,871 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:43,875 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:43,881 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:43,884 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:43,885 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:43,886 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:43,887 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:43,888 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:43,888 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:43,891 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:43,893 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:43,894 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:43,903 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:43,904 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:43,905 : INFO : EPOCH - 3 : training on 58956 raw words (48497 effective words) took 0.0s, 1006169 effective words/s
# 2019-11-03 19:30:43,915 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:43,920 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:43,921 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:43,921 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:43,922 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:43,926 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:43,932 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:43,932 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:43,934 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:43,935 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:43,937 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:43,954 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:43,956 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:43,957 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:43,962 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:43,964 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:43,964 : INFO : EPOCH - 4 : training on 58956 raw words (48530 effective words) took 0.1s, 939160 effective words/s
# 2019-11-03 19:30:43,976 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:43,981 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:43,990 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:43,991 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:43,996 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:43,997 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:43,999 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:43,999 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:44,002 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:44,003 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:44,005 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:44,008 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:44,017 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:44,021 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:44,023 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:44,025 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:44,026 : INFO : EPOCH - 5 : training on 58956 raw words (48469 effective words) took 0.1s, 911026 effective words/s
# 2019-11-03 19:30:44,037 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:44,041 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:44,045 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:44,048 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:44,049 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:44,052 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:44,056 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:44,062 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:44,063 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:44,064 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:44,065 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:44,069 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:44,070 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:44,076 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:44,080 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:44,082 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:44,082 : INFO : EPOCH - 6 : training on 58956 raw words (48522 effective words) took 0.0s, 999472 effective words/s
# 2019-11-03 19:30:44,091 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:44,095 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:44,098 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:44,099 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:44,103 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:44,104 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:44,109 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:44,112 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:44,114 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:44,116 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:44,118 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:44,119 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:44,131 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:44,132 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:44,135 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:44,137 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:44,138 : INFO : EPOCH - 7 : training on 58956 raw words (48405 effective words) took 0.0s, 984975 effective words/s
# 2019-11-03 19:30:44,150 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:44,153 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:44,159 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:44,160 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:44,162 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:44,165 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:44,166 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:44,168 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:44,174 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:44,175 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:44,176 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:44,181 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:44,185 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:44,188 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:44,189 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:44,192 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:44,193 : INFO : EPOCH - 8 : training on 58956 raw words (48559 effective words) took 0.0s, 1046007 effective words/s
# 2019-11-03 19:30:44,202 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:44,206 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:44,211 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:44,213 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:44,216 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:44,217 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:44,219 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:44,224 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:44,225 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:44,225 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:44,226 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:44,231 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:44,232 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:44,233 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:44,235 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:44,239 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:44,240 : INFO : EPOCH - 9 : training on 58956 raw words (48721 effective words) took 0.0s, 1237535 effective words/s
# 2019-11-03 19:30:44,249 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:44,254 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:44,255 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:44,259 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:44,263 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:44,264 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:44,264 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:44,266 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:44,268 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:44,270 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:44,270 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:44,271 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:44,272 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:44,279 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:44,283 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:44,284 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:44,284 : INFO : EPOCH - 10 : training on 58956 raw words (48559 effective words) took 0.0s, 1263049 effective words/s
# 2019-11-03 19:30:44,293 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:44,297 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:44,301 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:44,307 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:44,308 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:44,310 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:44,311 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:44,312 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:44,314 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:44,315 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:44,316 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:44,320 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:44,328 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:44,329 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:44,332 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:44,333 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:44,333 : INFO : EPOCH - 11 : training on 58956 raw words (48596 effective words) took 0.0s, 1152313 effective words/s
# 2019-11-03 19:30:44,345 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:44,347 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:44,347 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:44,349 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:44,354 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:44,358 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:44,362 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:44,364 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:44,365 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:44,366 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:44,367 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:44,367 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:44,368 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:44,374 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:44,376 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:44,378 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:44,379 : INFO : EPOCH - 12 : training on 58956 raw words (48477 effective words) took 0.0s, 1247554 effective words/s
# 2019-11-03 19:30:44,388 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:44,394 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:44,395 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:44,396 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:44,397 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:44,398 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:44,399 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:44,400 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:44,406 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:44,407 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:44,408 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:44,413 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:44,414 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:44,416 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:44,422 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:44,425 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:44,425 : INFO : EPOCH - 13 : training on 58956 raw words (48601 effective words) took 0.0s, 1214044 effective words/s
# 2019-11-03 19:30:44,434 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:44,437 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:44,438 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:44,440 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:44,444 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:44,445 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:44,446 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:44,452 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:44,454 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:44,455 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:44,456 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:44,460 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:44,461 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:44,462 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:44,469 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:44,470 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:44,471 : INFO : EPOCH - 14 : training on 58956 raw words (48638 effective words) took 0.0s, 1240330 effective words/s
# 2019-11-03 19:30:44,479 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:44,483 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:44,483 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:44,484 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:44,488 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:44,493 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:44,494 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:44,496 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:44,497 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:44,501 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:44,502 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:44,502 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:44,510 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:44,511 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:44,511 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:44,516 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:44,517 : INFO : EPOCH - 15 : training on 58956 raw words (48727 effective words) took 0.0s, 1242603 effective words/s
# 2019-11-03 19:30:44,526 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:44,526 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:44,531 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:44,533 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:44,533 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:44,535 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:44,538 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:44,539 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:44,541 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:44,545 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:44,547 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:44,551 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:44,554 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:44,557 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:44,558 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:44,561 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:44,561 : INFO : EPOCH - 16 : training on 58956 raw words (48624 effective words) took 0.0s, 1266519 effective words/s
# 2019-11-03 19:30:44,570 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:44,573 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:44,579 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:44,582 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:44,585 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:44,587 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:44,589 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:44,590 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:44,591 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:44,591 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:44,592 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:44,593 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:44,598 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:44,602 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:44,603 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:44,606 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:44,606 : INFO : EPOCH - 17 : training on 58956 raw words (48614 effective words) took 0.0s, 1256094 effective words/s
# 2019-11-03 19:30:44,614 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:44,615 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:44,618 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:44,621 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:44,624 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:44,625 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:44,626 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:44,628 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:44,629 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:44,635 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:44,638 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:44,643 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:44,644 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:44,645 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:44,654 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:44,654 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:44,655 : INFO : EPOCH - 18 : training on 58956 raw words (48639 effective words) took 0.0s, 1145283 effective words/s
# 2019-11-03 19:30:44,664 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:44,667 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:44,667 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:44,668 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:44,669 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:44,669 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:44,676 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:44,679 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:44,680 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:44,683 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:44,683 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:44,686 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:44,695 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:44,699 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:44,700 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:44,703 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:44,704 : INFO : EPOCH - 19 : training on 58956 raw words (48664 effective words) took 0.0s, 1152326 effective words/s
# 2019-11-03 19:30:44,712 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:44,716 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:44,720 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:44,722 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:44,722 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:44,724 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:44,727 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:44,731 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:44,733 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:44,734 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:44,734 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:44,740 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:44,741 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:44,742 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:44,749 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:44,751 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:44,751 : INFO : EPOCH - 20 : training on 58956 raw words (48527 effective words) took 0.0s, 1253926 effective words/s
# 2019-11-03 19:30:44,761 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:44,763 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:44,771 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:44,772 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:44,774 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:44,778 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:44,780 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:44,780 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:44,781 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:44,781 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:44,783 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:44,787 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:44,790 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:44,791 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:44,792 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:44,796 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:44,796 : INFO : EPOCH - 21 : training on 58956 raw words (48612 effective words) took 0.0s, 1276626 effective words/s
# 2019-11-03 19:30:44,805 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:44,806 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:44,811 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:44,813 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:44,813 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:44,814 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:44,815 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:44,818 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:44,825 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:44,827 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:44,828 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:44,828 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:44,831 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:44,838 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:44,841 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:44,842 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:44,842 : INFO : EPOCH - 22 : training on 58956 raw words (48672 effective words) took 0.0s, 1225827 effective words/s
# 2019-11-03 19:30:44,851 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:44,852 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:44,853 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:44,856 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:44,858 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:44,859 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:44,864 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:44,867 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:44,868 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:44,869 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:44,871 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:44,875 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:44,884 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:44,885 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:44,886 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:44,888 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:44,888 : INFO : EPOCH - 23 : training on 58956 raw words (48647 effective words) took 0.0s, 1233401 effective words/s
# 2019-11-03 19:30:44,897 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:44,898 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:44,900 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:44,903 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:44,904 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:44,908 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:44,909 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:44,910 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:44,912 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:44,913 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:44,916 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:44,924 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:44,928 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:44,929 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:44,930 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:44,933 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:44,934 : INFO : EPOCH - 24 : training on 58956 raw words (48355 effective words) took 0.0s, 1227372 effective words/s
# 2019-11-03 19:30:44,942 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:44,946 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:44,948 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:44,952 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:44,955 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:44,956 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:44,961 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:44,961 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:44,963 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:44,963 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:44,964 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:44,968 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:44,969 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:44,973 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:44,977 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:44,978 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:44,978 : INFO : EPOCH - 25 : training on 58956 raw words (48599 effective words) took 0.0s, 1268243 effective words/s
# 2019-11-03 19:30:44,987 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:44,989 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:44,990 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:44,992 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:44,993 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:44,996 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:45,000 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:45,002 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:45,005 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:45,007 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:45,008 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:45,010 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:45,018 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:45,022 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:45,023 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:45,025 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:45,025 : INFO : EPOCH - 26 : training on 58956 raw words (48535 effective words) took 0.0s, 1210940 effective words/s
# 2019-11-03 19:30:45,033 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:45,037 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:45,040 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:45,043 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:45,044 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:45,047 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:45,049 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:45,053 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:45,055 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:45,056 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:45,056 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:45,058 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:45,061 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:45,064 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:45,065 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:45,069 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:45,070 : INFO : EPOCH - 27 : training on 58956 raw words (48744 effective words) took 0.0s, 1266273 effective words/s
# 2019-11-03 19:30:45,079 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:45,084 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:45,088 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:45,089 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:45,091 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:45,092 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:45,093 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:45,093 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:45,094 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:45,094 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:45,097 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:45,105 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:45,106 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:45,108 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:45,115 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:45,117 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:45,117 : INFO : EPOCH - 28 : training on 58956 raw words (48443 effective words) took 0.0s, 1191190 effective words/s
# 2019-11-03 19:30:45,127 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:45,131 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:45,134 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:45,135 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:45,137 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:45,137 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:45,139 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:45,142 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:45,146 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:45,147 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:45,148 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:45,151 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:45,152 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:45,155 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:45,162 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:45,163 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:45,164 : INFO : EPOCH - 29 : training on 58956 raw words (48597 effective words) took 0.0s, 1236663 effective words/s
# ...
# 2019-11-03 19:30:48,130 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:48,132 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:48,134 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:48,135 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:48,138 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:48,142 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:48,144 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:48,145 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:48,145 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:48,146 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:48,148 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:48,149 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:48,150 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:48,158 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:48,160 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:48,160 : INFO : EPOCH - 93 : training on 58956 raw words (48598 effective words) took 0.0s, 1206780 effective words/s
# 2019-11-03 19:30:48,169 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:48,174 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:48,177 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:48,177 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:48,180 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:48,183 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:48,186 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:48,187 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:48,190 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:48,191 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:48,192 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:48,194 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:48,195 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:48,204 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:48,205 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:48,206 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:48,207 : INFO : EPOCH - 94 : training on 58956 raw words (48617 effective words) took 0.0s, 1219975 effective words/s
# 2019-11-03 19:30:48,215 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:48,217 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:48,220 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:48,225 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:48,226 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:48,227 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:48,228 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:48,229 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:48,233 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:48,235 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:48,238 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:48,243 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:48,244 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:48,246 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:48,251 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:48,253 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:48,254 : INFO : EPOCH - 95 : training on 58956 raw words (48634 effective words) took 0.0s, 1202953 effective words/s
# 2019-11-03 19:30:48,264 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:48,268 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:48,269 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:48,270 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:48,271 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:48,272 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:48,277 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:48,281 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:48,281 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:48,283 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:48,284 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:48,286 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:48,288 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:48,298 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:48,299 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:48,300 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:48,301 : INFO : EPOCH - 96 : training on 58956 raw words (48475 effective words) took 0.0s, 1207689 effective words/s
# 2019-11-03 19:30:48,309 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:48,312 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:48,313 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:48,314 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:48,319 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:48,321 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:48,322 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:48,323 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:48,325 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:48,326 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:48,332 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:48,339 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:48,340 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:48,342 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:48,346 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:48,347 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:48,348 : INFO : EPOCH - 97 : training on 58956 raw words (48569 effective words) took 0.0s, 1184864 effective words/s
# 2019-11-03 19:30:48,358 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:48,360 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:48,361 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:48,365 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:48,370 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:48,371 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:48,372 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:48,374 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:48,375 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:48,379 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:48,381 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:48,382 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:48,388 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:48,390 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:48,391 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:48,395 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:48,396 : INFO : EPOCH - 98 : training on 58956 raw words (48610 effective words) took 0.0s, 1185213 effective words/s
# 2019-11-03 19:30:48,405 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:48,411 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:48,419 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:48,421 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:48,424 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:48,428 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:48,429 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:48,430 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:48,431 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:48,431 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:48,432 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:48,439 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:48,441 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:48,442 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:48,445 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:48,448 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:48,448 : INFO : EPOCH - 99 : training on 58956 raw words (48559 effective words) took 0.0s, 1062051 effective words/s
# 2019-11-03 19:30:48,460 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-11-03 19:30:48,463 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-11-03 19:30:48,464 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-11-03 19:30:48,471 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-11-03 19:30:48,472 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-11-03 19:30:48,473 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-11-03 19:30:48,475 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-11-03 19:30:48,480 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-11-03 19:30:48,481 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-03 19:30:48,483 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-03 19:30:48,485 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-03 19:30:48,490 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-03 19:30:48,494 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-03 19:30:48,499 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-03 19:30:48,500 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-03 19:30:48,502 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-03 19:30:48,503 : INFO : EPOCH - 100 : training on 58956 raw words (48509 effective words) took 0.0s, 1046339 effective words/s
# 2019-11-03 19:30:48,503 : INFO : training on a 5895600 raw words (4858628 effective words) took 4.8s, 1022624 effective words/s
# 2019-11-03 19:30:48,504 : INFO : Vocabulary size: 6702
# 2019-11-03 19:30:48,505 : INFO : Word2Vec trained
# 2019-11-03 19:30:48,505 : INFO : Fit LabelEncoder
# 2019-11-03 19:30:48,508 : INFO : Fit Tokenizer
# 2019-11-03 19:30:48,600 : INFO : Number of unique words: 6703
# 2019-11-03 19:30:48,600 : INFO : Create Embedding matrix
# 2019-11-03 19:30:48,872 : INFO : Embedding matrix: (6703, 300)
# 2019-11-03 19:30:48,873 : INFO : Build Keras model
# 2019-11-03 19:30:48,873 : INFO : x_train shape: (4177, 1000)
# 2019-11-03 19:30:48,874 : INFO : y_train shape: (4177, 2)
# 2019-11-03 19:30:49,262 : INFO : None
# /Users/yuhuang/anaconda3/envs/deeplearning/lib/python3.7/site-packages/keras/callbacks/callbacks.py:998: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '
# 2019-11-03 19:30:49,265 : INFO : Fit Keras model
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 1000, 300)         2010900
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 512)               1665024
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 3,676,950
# Trainable params: 1,666,050
# Non-trainable params: 2,010,900
# _________________________________________________________________
# Epoch 1/5
# 4177/4177 [==============================] - 414s 99ms/step - loss: 0.1263 - accuracy: 0.9528
# Epoch 2/5
# /Users/yuhuang/anaconda3/envs/deeplearning/lib/python3.7/site-packages/keras/callbacks/callbacks.py:846: RuntimeWarning: Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# /Users/yuhuang/anaconda3/envs/deeplearning/lib/python3.7/site-packages/keras/callbacks/callbacks.py:1042: RuntimeWarning: Reduce LR on plateau conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,lr
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# 4177/4177 [==============================] - 397s 95ms/step - loss: 0.0522 - accuracy: 0.9823
# Epoch 3/5
# 4177/4177 [==============================] - 400s 96ms/step - loss: 0.0458 - accuracy: 0.9849
# Epoch 4/5
# 4177/4177 [==============================] - 403s 97ms/step - loss: 0.0423 - accuracy: 0.9864
# Epoch 5/5
# 4177/4177 [==============================] - 408s 98ms/step - loss: 0.0387 - accuracy: 0.9868
# 2019-11-03 20:04:32,109 : INFO : Done
# 1393/1393 [==============================] - 63s 45ms/step
# Confusion Matrix:  [[1207    5]
#  [  21  160]]
# LABEL: ham
# TEXT : U r too much close to my heart. If u go away i will be shattered. Plz stay with me.
# /n============================================
# PREDICTION: {'label': 'ham', 'confidence': 0.9996090531349182, 'elapsed_time': 0.5015852451324463}
